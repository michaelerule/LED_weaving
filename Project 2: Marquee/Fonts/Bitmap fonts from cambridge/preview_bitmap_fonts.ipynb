# %%
# %matplotlib inline
#from neurotools.nlab import *
import os,sys
from numpy import *
from pylab import *
fontdir = './ucs-fonts'

# %%
fontfiles = [f for f in os.listdir(fontdir) if '.bdf' in f]
print('Available fonts:','\n\t'.join(fontfiles))
# Out:
# Available fonts: 9x15.bdf
# 	6x12.bdf
# 	7x13O.bdf
# 	5x7.bdf
# 	helvR12.bdf
# 	7x14.bdf
# 	6x9.bdf
# 	9x18B.bdf
# 	8x13.bdf
# 	5x8.bdf
# 	9x18.bdf
# 	6x13O.bdf
# 	4x6.bdf
# 	8x13O.bdf
# 	clR6x12.bdf
# 	7x13.bdf
# 	6x13B.bdf
# 	6x13.bdf
# 	6x10.bdf
# 	7x13B.bdf
# 	8x13B.bdf
# 	7x14B.bdf
# 	10x20.bdf
# 	9x15B.bdf

# %%
fontfile = '5x7.bdf'

with open(fontdir+os.sep+fontfile,'r') as f:
    data = f.readlines()

# %%
def tokenize(data):
    words = []
    in_token = False
    for token in data:
        if 'STARTCHAR' in token:
            in_token=True
        if in_token:
            words.append(token)
        if 'ENDCHAR' in token:
            yield words
            words=[]
            in_token=False

tokens = list(tokenize(data))

# %%
def parsechar(token):
    def maybeint(s):
        try:
            return int(s)
        except:
            return s
    properties = {k[0]:maybeint(k[1]) for k in [s.split() for s in token[:5]]}
    chardata = [int(s.strip(),16) for s in token[6:-1]]
    width = properties['DWIDTH']
    chardata = ["{0:b}".format(s).zfill(8)[:width] for s in chardata]
    asints   = int32([[c=='1' for c in line] for line in chardata])
    textdata = '\n'.join(chardata)
    textdata = textdata.replace('0','  ').replace('1','██')
    print(properties)
    print(textdata)
    
    return properties,chardata,asints
    
alldata = array([parsechar(k)[2] for k in tokens])
# Out:
# {'STARTCHAR': 'char0', 'ENCODING': 0, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#
# ██  ██
#
# ██  ██
#
# {'STARTCHAR': 'space', 'ENCODING': 32, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
#
#
#
# {'STARTCHAR': 'exclam', 'ENCODING': 33, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
#   ██
#
#   ██
#
# {'STARTCHAR': 'quotedbl', 'ENCODING': 34, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██  ██
#
#
#
#
# {'STARTCHAR': 'numbersign', 'ENCODING': 35, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ████████
# ██  ██
# ████████
# ██  ██
#
# {'STARTCHAR': 'dollar', 'ENCODING': 36, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██████
# ████
#     ██
# ██████
#   ██
# {'STARTCHAR': 'percent', 'ENCODING': 37, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
#     ██
#   ██
# ██
#     ██
#
# {'STARTCHAR': 'ampersand', 'ENCODING': 38, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
#   ██
# ██  ██
#   ██  ██
#
# {'STARTCHAR': 'quotesingle', 'ENCODING': 39, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
#
#
#
#
# {'STARTCHAR': 'parenleft', 'ENCODING': 40, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
#   ██
#   ██
#   ██
#     ██
# {'STARTCHAR': 'parenright', 'ENCODING': 41, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
#   ██
#   ██
#   ██
#   ██
# ██
# {'STARTCHAR': 'asterisk', 'ENCODING': 42, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
# ██████
#   ██
# ██  ██
#
# {'STARTCHAR': 'plus', 'ENCODING': 43, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
# ██████
#   ██
#   ██
#
# {'STARTCHAR': 'comma', 'ENCODING': 44, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
#
#   ██
# ██
# {'STARTCHAR': 'hyphen', 'ENCODING': 45, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
# ██████
#
#
#
# {'STARTCHAR': 'period', 'ENCODING': 46, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
#
#   ██
#
# {'STARTCHAR': 'slash', 'ENCODING': 47, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#     ██
#   ██
# ██
# ██
#
# {'STARTCHAR': 'zero', 'ENCODING': 48, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
# ██████
# ██  ██
#   ██
#
# {'STARTCHAR': 'one', 'ENCODING': 49, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ████
#   ██
#   ██
# ██████
#
# {'STARTCHAR': 'two', 'ENCODING': 50, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
#     ██
#   ██
# ██████
#
# {'STARTCHAR': 'three', 'ENCODING': 51, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#     ██
#   ██
#     ██
# ████
#
# {'STARTCHAR': 'four', 'ENCODING': 52, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██  ██
# ██████
#     ██
#     ██
#
# {'STARTCHAR': 'five', 'ENCODING': 53, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
# ██
# ████
#     ██
# ████
#
# {'STARTCHAR': 'six', 'ENCODING': 54, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
# ██
# ████
# ██  ██
#   ██
#
# {'STARTCHAR': 'seven', 'ENCODING': 55, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#     ██
#   ██
# ██
# ██
#
# {'STARTCHAR': 'eight', 'ENCODING': 56, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
# ██  ██
#   ██
# ██  ██
# ████
#
# {'STARTCHAR': 'nine', 'ENCODING': 57, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
#   ████
#     ██
# ████
#
# {'STARTCHAR': 'colon', 'ENCODING': 58, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ██
#
#
#   ██
#
# {'STARTCHAR': 'semicolon', 'ENCODING': 59, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ██
#
#
#   ██
# ██
# {'STARTCHAR': 'less', 'ENCODING': 60, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
# ██
#   ██
#     ██
#
# {'STARTCHAR': 'equal', 'ENCODING': 61, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ██████
#
# ██████
#
#
# {'STARTCHAR': 'greater', 'ENCODING': 62, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
#   ██
#     ██
#   ██
# ██
#
# {'STARTCHAR': 'question', 'ENCODING': 63, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
#     ██
#   ██
#
#   ██
#
# {'STARTCHAR': 'at', 'ENCODING': 64, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
# ██  ██
# ██  ██
# ██
#   ████
#
# {'STARTCHAR': 'A', 'ENCODING': 65, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
# ██████
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'B', 'ENCODING': 66, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
# ██  ██
# ████
# ██  ██
# ████
#
# {'STARTCHAR': 'C', 'ENCODING': 67, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
# ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'D', 'ENCODING': 68, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
# ██  ██
# ██  ██
# ██  ██
# ████
#
# {'STARTCHAR': 'E', 'ENCODING': 69, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
# ██
# ████
# ██
# ██████
#
# {'STARTCHAR': 'F', 'ENCODING': 70, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
# ██
# ████
# ██
# ██
#
# {'STARTCHAR': 'G', 'ENCODING': 71, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
# ██
# ██  ██
# ██  ██
#   ████
#
# {'STARTCHAR': 'H', 'ENCODING': 72, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██  ██
# ██████
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'I', 'ENCODING': 73, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#   ██
#   ██
#   ██
# ██████
#
# {'STARTCHAR': 'J', 'ENCODING': 74, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#     ██
#     ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'K', 'ENCODING': 75, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██  ██
# ████
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'L', 'ENCODING': 76, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ██
# ██
# ██
# ██████
#
# {'STARTCHAR': 'M', 'ENCODING': 77, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██████
# ██████
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'N', 'ENCODING': 78, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
# ██  ██
# ██████
# ██  ██
# ██
#
# {'STARTCHAR': 'O', 'ENCODING': 79, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
# ██  ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'P', 'ENCODING': 80, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
# ██  ██
# ████
# ██
# ██
#
# {'STARTCHAR': 'Q', 'ENCODING': 81, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
# ██  ██
# ██  ██
#   ██
#     ██
# {'STARTCHAR': 'R', 'ENCODING': 82, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
# ██  ██
# ████
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'S', 'ENCODING': 83, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
# ██
#   ██
#     ██
# ████
#
# {'STARTCHAR': 'T', 'ENCODING': 84, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#   ██
#   ██
#   ██
#   ██
#
# {'STARTCHAR': 'U', 'ENCODING': 85, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██  ██
# ██  ██
# ██  ██
# ██████
#
# {'STARTCHAR': 'V', 'ENCODING': 86, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██  ██
# ██  ██
# ██████
#   ██
#
# {'STARTCHAR': 'W', 'ENCODING': 87, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██  ██
# ██████
# ██████
# ██  ██
#
# {'STARTCHAR': 'X', 'ENCODING': 88, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██  ██
#   ██
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'Y', 'ENCODING': 89, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██  ██
#   ██
#   ██
#   ██
#
# {'STARTCHAR': 'Z', 'ENCODING': 90, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#     ██
#   ██
# ██
# ██████
#
# {'STARTCHAR': 'bracketleft', 'ENCODING': 91, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ██
#   ██
#   ██
#   ████
#
# {'STARTCHAR': 'backslash', 'ENCODING': 92, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ██
#   ██
#     ██
#     ██
#
# {'STARTCHAR': 'bracketright', 'ENCODING': 93, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
#   ██
#   ██
#   ██
# ████
#
# {'STARTCHAR': 'asciicircum', 'ENCODING': 94, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
#
#
#
#
# {'STARTCHAR': 'underscore', 'ENCODING': 95, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
#
#
# ██████
# {'STARTCHAR': 'grave', 'ENCODING': 96, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#     ██
#
#
#
#
# {'STARTCHAR': 'a', 'ENCODING': 97, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ████
# ██  ██
# ██  ██
#   ████
#
# {'STARTCHAR': 'b', 'ENCODING': 98, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ████
# ██  ██
# ██  ██
# ████
#
# {'STARTCHAR': 'c', 'ENCODING': 99, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ████
# ██
# ██
#   ████
#
# {'STARTCHAR': 'd', 'ENCODING': 100, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ████
# ██  ██
# ██  ██
#   ████
#
# {'STARTCHAR': 'e', 'ENCODING': 101, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ██
# ██  ██
# ████
#   ████
#
# {'STARTCHAR': 'f', 'ENCODING': 102, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
# ██████
#   ██
#   ██
#
# {'STARTCHAR': 'g', 'ENCODING': 103, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ████
# ██  ██
#   ████
#     ██
# ████
# {'STARTCHAR': 'h', 'ENCODING': 104, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ████
# ██  ██
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'i', 'ENCODING': 105, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#
# ████
#   ██
# ██████
#
# {'STARTCHAR': 'j', 'ENCODING': 106, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#
#     ██
#     ██
#     ██
# ████
# {'STARTCHAR': 'k', 'ENCODING': 107, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ██  ██
# ████
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'l', 'ENCODING': 108, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
#   ██
#   ██
#   ██
# ██████
#
# {'STARTCHAR': 'm', 'ENCODING': 109, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ██  ██
# ██████
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'n', 'ENCODING': 110, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ████
# ██  ██
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'o', 'ENCODING': 111, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ██
# ██  ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'p', 'ENCODING': 112, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ████
# ██  ██
# ████
# ██
# ██
# {'STARTCHAR': 'q', 'ENCODING': 113, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ████
# ██  ██
# ██  ██
#   ████
#     ██
# {'STARTCHAR': 'r', 'ENCODING': 114, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ██  ██
# ████
# ██
# ██
#
# {'STARTCHAR': 's', 'ENCODING': 115, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ████
# ████
#     ██
# ████
#
# {'STARTCHAR': 't', 'ENCODING': 116, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██████
#   ██
#   ██
#     ██
#
# {'STARTCHAR': 'u', 'ENCODING': 117, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ██  ██
# ██  ██
# ██  ██
#   ████
#
# {'STARTCHAR': 'v', 'ENCODING': 118, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ██  ██
# ██  ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'w', 'ENCODING': 119, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ██  ██
# ██  ██
# ██████
# ██  ██
#
# {'STARTCHAR': 'x', 'ENCODING': 120, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ██  ██
#   ██
#   ██
# ██  ██
#
# {'STARTCHAR': 'y', 'ENCODING': 121, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ██  ██
# ██  ██
#   ████
#     ██
# ████
# {'STARTCHAR': 'z', 'ENCODING': 122, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ██████
#     ██
#   ██
# ██████
#
# {'STARTCHAR': 'braceleft', 'ENCODING': 123, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
# ████
#   ██
#   ██
#     ██
# {'STARTCHAR': 'bar', 'ENCODING': 124, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
#   ██
#   ██
#   ██
#
# {'STARTCHAR': 'braceright', 'ENCODING': 125, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
#   ██
#   ████
#   ██
#   ██
# ██
# {'STARTCHAR': 'asciitilde', 'ENCODING': 126, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██  ██
# ██  ██
#
#
#
#
# {'STARTCHAR': 'space', 'ENCODING': 160, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
#
#
#
# {'STARTCHAR': 'exclamdown', 'ENCODING': 161, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#
#   ██
#   ██
#   ██
#
# {'STARTCHAR': 'cent', 'ENCODING': 162, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██████
# ██
# ██████
#   ██
#
# {'STARTCHAR': 'sterling', 'ENCODING': 163, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
#   ████
#   ██
# ██  ██
#
# {'STARTCHAR': 'currency', 'ENCODING': 164, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ██    ██
#   ████
#   ████
# ██    ██
#
# {'STARTCHAR': 'yen', 'ENCODING': 165, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
# ██████
#   ██
#   ██
#
# {'STARTCHAR': 'brokenbar', 'ENCODING': 166, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
#
#   ██
#   ██
#
# {'STARTCHAR': 'section', 'ENCODING': 167, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
# ████
# ██  ██
#   ████
#     ██
# ████
# {'STARTCHAR': 'dieresis', 'ENCODING': 168, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#
#
#
#
#
# {'STARTCHAR': 'copyright', 'ENCODING': 169, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
# ██    ██
# ████  ██
# ████  ██
# ██    ██
#   ████
# {'STARTCHAR': 'ordfeminine', 'ENCODING': 170, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
# ██  ██
#   ████
#
# ██████
#
# {'STARTCHAR': 'guillemotleft', 'ENCODING': 171, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ██  ██
# ██  ██
#   ██  ██
#
#
# {'STARTCHAR': 'logicalnot', 'ENCODING': 172, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
# ██████
#     ██
#
#
# {'STARTCHAR': 'hyphen', 'ENCODING': 173, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
# ██████
#
#
#
# {'STARTCHAR': 'registered', 'ENCODING': 174, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
# ████████
# ████  ██
#   ████
#
#
# {'STARTCHAR': 'macron', 'ENCODING': 175, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#
#
#
#
#
# {'STARTCHAR': 'degree', 'ENCODING': 176, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
#   ██
#
#
#
# {'STARTCHAR': 'plusminus', 'ENCODING': 177, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██████
#   ██
#
# ██████
#
# {'STARTCHAR': 'twosuperior', 'ENCODING': 178, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
#   ██
# ██
# ████
#
#
# {'STARTCHAR': 'threesuperior', 'ENCODING': 179, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
#   ██
# ██
#   ██
# ██
#
# {'STARTCHAR': 'acute', 'ENCODING': 180, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
#
#
#
#
# {'STARTCHAR': 'mu', 'ENCODING': 181, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ██  ██
# ██  ██
# ██  ██
# ████
# ██
# {'STARTCHAR': 'paragraph', 'ENCODING': 182, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██████
# ████  ██
# ████  ██
#   ██  ██
#   ██  ██
#
# {'STARTCHAR': 'periodcentered', 'ENCODING': 183, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#   ██
#
#
#
# {'STARTCHAR': 'cedilla', 'ENCODING': 184, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
#     ██
#   ██
#
# {'STARTCHAR': 'onesuperior', 'ENCODING': 185, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ████
#   ██
#   ██
#
#
# {'STARTCHAR': 'ordmasculine', 'ENCODING': 186, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
#   ██
#
# ██████
#
# {'STARTCHAR': 'guillemotright', 'ENCODING': 187, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ██  ██
#   ██  ██
# ██  ██
#
#
# {'STARTCHAR': 'onequarter', 'ENCODING': 188, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ██
# ██
#   ██  ██
#   ██████
#       ██
# {'STARTCHAR': 'onehalf', 'ENCODING': 189, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ██
# ██  ████
#       ██
#     ██
#     ████
# {'STARTCHAR': 'threequarters', 'ENCODING': 190, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
#   ██
# ██
#   ██  ██
# ██  ████
#       ██
# {'STARTCHAR': 'questiondown', 'ENCODING': 191, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#
#   ██
# ██
#   ████
#
# {'STARTCHAR': 'Agrave', 'ENCODING': 192, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
#   ██
# ██  ██
# ██████
# ██  ██
#
# {'STARTCHAR': 'Aacute', 'ENCODING': 193, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
# ██  ██
# ██████
# ██  ██
#
# {'STARTCHAR': 'Acircumflex', 'ENCODING': 194, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
#   ██
# ██  ██
# ██████
# ██  ██
#
# {'STARTCHAR': 'Atilde', 'ENCODING': 195, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
# ████
# ██  ██
# ██████
# ██  ██
#
# {'STARTCHAR': 'Adieresis', 'ENCODING': 196, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
# ██  ██
# ██████
# ██  ██
#
# {'STARTCHAR': 'Aring', 'ENCODING': 197, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
# ██  ██
# ██████
# ██  ██
#
# {'STARTCHAR': 'AE', 'ENCODING': 198, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██████
# ██  ██
# ████████
# ██  ██
# ██  ████
#
# {'STARTCHAR': 'Ccedilla', 'ENCODING': 199, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
# ██
# ██  ██
#   ██
# ██
# {'STARTCHAR': 'Egrave', 'ENCODING': 200, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ██████
# ████
# ██
# ██████
#
# {'STARTCHAR': 'Eacute', 'ENCODING': 201, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
# ██████
# ████
# ██
# ██████
#
# {'STARTCHAR': 'Ecircumflex', 'ENCODING': 202, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
# ██████
# ████
# ██
# ██████
#
# {'STARTCHAR': 'Edieresis', 'ENCODING': 203, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██████
# ████
# ██
# ██████
#
# {'STARTCHAR': 'Igrave', 'ENCODING': 204, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ██████
#   ██
#   ██
# ██████
#
# {'STARTCHAR': 'Iacute', 'ENCODING': 205, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
# ██████
#   ██
#   ██
# ██████
#
# {'STARTCHAR': 'Icircumflex', 'ENCODING': 206, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██████
#   ██
#   ██
# ██████
#
# {'STARTCHAR': 'Idieresis', 'ENCODING': 207, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
#   ██
#   ██
# ██████
#
# {'STARTCHAR': 'Eth', 'ENCODING': 208, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#   ██  ██
# ████  ██
#   ██  ██
# ██████
#
# {'STARTCHAR': 'Ntilde', 'ENCODING': 209, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██  ██
# ██  ██
# ██████
# ██████
# ██  ██
#
# {'STARTCHAR': 'Ograve', 'ENCODING': 210, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
#   ██
# ██  ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'Oacute', 'ENCODING': 211, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
# ██  ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'Ocircumflex', 'ENCODING': 212, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
# ██  ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'Otilde', 'ENCODING': 213, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██████
# ██████
# ██  ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'Odieresis', 'ENCODING': 214, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
# ██  ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'multiply', 'ENCODING': 215, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ██  ██
#   ██
# ██  ██
#
#
# {'STARTCHAR': 'Oslash', 'ENCODING': 216, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
# ██  ██
# ██████
# ██  ██
# ████
#
# {'STARTCHAR': 'Ugrave', 'ENCODING': 217, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
#   ██
# ██  ██
# ██  ██
# ██████
#
# {'STARTCHAR': 'Uacute', 'ENCODING': 218, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
# ██  ██
# ██  ██
# ██████
#
# {'STARTCHAR': 'Ucircumflex', 'ENCODING': 219, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#
# ██  ██
# ██  ██
# ██████
#
# {'STARTCHAR': 'Udieresis', 'ENCODING': 220, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#
# ██  ██
# ██  ██
# ██████
#
# {'STARTCHAR': 'Yacute', 'ENCODING': 221, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#
# ██  ██
#   ██
#   ██
#
# {'STARTCHAR': 'Thorn', 'ENCODING': 222, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ████
# ██  ██
# ████
# ██
#
# {'STARTCHAR': 'germandbls', 'ENCODING': 223, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
# ████
# ██  ██
# ██████
# ██
# {'STARTCHAR': 'agrave', 'ENCODING': 224, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
#   ██
#   ████
# ██  ██
#   ████
#
# {'STARTCHAR': 'aacute', 'ENCODING': 225, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
#   ████
# ██  ██
#   ████
#
# {'STARTCHAR': 'acircumflex', 'ENCODING': 226, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#
#   ████
# ██  ██
#   ████
#
# {'STARTCHAR': 'atilde', 'ENCODING': 227, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██  ██
# ██  ██
#   ████
# ██  ██
#   ████
#
# {'STARTCHAR': 'adieresis', 'ENCODING': 228, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#
#   ████
# ██  ██
#   ████
#
# {'STARTCHAR': 'aring', 'ENCODING': 229, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#
#   ████
# ██  ██
#   ████
#
# {'STARTCHAR': 'ae', 'ENCODING': 230, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ██████
# ██  ████
# ██  ██
#   ██████
#
# {'STARTCHAR': 'ccedilla', 'ENCODING': 231, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ██
# ██  ██
# ██
#   ████
#   ██
# {'STARTCHAR': 'egrave', 'ENCODING': 232, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
#   ██
# ██  ██
# ████
#   ████
#
# {'STARTCHAR': 'eacute', 'ENCODING': 233, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
# ██  ██
# ████
#   ████
#
# {'STARTCHAR': 'ecircumflex', 'ENCODING': 234, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
#   ██
# ██  ██
# ████
#   ████
#
# {'STARTCHAR': 'edieresis', 'ENCODING': 235, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
# ██  ██
# ████
#   ████
#
# {'STARTCHAR': 'igrave', 'ENCODING': 236, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
#   ██
#   ██
#   ██
# ██████
#
# {'STARTCHAR': 'iacute', 'ENCODING': 237, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
# ████
#   ██
#   ██
# ██████
#
# {'STARTCHAR': 'icircumflex', 'ENCODING': 238, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
#   ██
#   ██
# ██████
#
# {'STARTCHAR': 'idieresis', 'ENCODING': 239, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#
# ████
#   ██
# ██████
#
# {'STARTCHAR': 'eth', 'ENCODING': 240, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
#   ████
# ██  ██
#   ██
#
# {'STARTCHAR': 'ntilde', 'ENCODING': 241, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██  ██
# ██  ██
# ████
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'ograve', 'ENCODING': 242, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
#   ██
#   ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'oacute', 'ENCODING': 243, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
#   ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'ocircumflex', 'ENCODING': 244, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#
#   ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'otilde', 'ENCODING': 245, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#
#   ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'odieresis', 'ENCODING': 246, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#
#   ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'divide', 'ENCODING': 247, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#
# ██████
#
#   ██
#
# {'STARTCHAR': 'oslash', 'ENCODING': 248, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ████
# ██  ██
# ██  ██
# ████
#
# {'STARTCHAR': 'ugrave', 'ENCODING': 249, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
#   ██
# ██  ██
# ██  ██
#   ████
#
# {'STARTCHAR': 'uacute', 'ENCODING': 250, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
# ██  ██
# ██  ██
#   ████
#
# {'STARTCHAR': 'ucircumflex', 'ENCODING': 251, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#
# ██  ██
# ██  ██
#   ████
#
# {'STARTCHAR': 'udieresis', 'ENCODING': 252, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#
# ██  ██
# ██  ██
#   ████
#
# {'STARTCHAR': 'yacute', 'ENCODING': 253, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
# ██  ██
# ██████
#     ██
# ████
# {'STARTCHAR': 'thorn', 'ENCODING': 254, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ██
# ████
# ██  ██
# ████
# ██
# {'STARTCHAR': 'ydieresis', 'ENCODING': 255, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#
# ██  ██
# ██████
#     ██
# ████
# {'STARTCHAR': 'Amacron', 'ENCODING': 256, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#   ██
# ██  ██
# ██████
# ██  ██
#
# {'STARTCHAR': 'amacron', 'ENCODING': 257, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#
#   ████
# ██  ██
#   ████
#
# {'STARTCHAR': 'Abreve', 'ENCODING': 258, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
# ██  ██
# ██████
# ██  ██
#
# {'STARTCHAR': 'abreve', 'ENCODING': 259, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
#   ████
# ██  ██
#   ████
#
# {'STARTCHAR': 'Aogonek', 'ENCODING': 260, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ██
# ██  ██
# ██████
# ██  ██
#     ██
# {'STARTCHAR': 'aogonek', 'ENCODING': 261, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#   ████
# ██  ██
#   ████
#     ██
# {'STARTCHAR': 'Cacute', 'ENCODING': 262, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
# ██  ██
# ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'cacute', 'ENCODING': 263, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
# ██  ██
# ██
#   ████
#
# {'STARTCHAR': 'Ccircumflex', 'ENCODING': 264, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
# ██  ██
# ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'ccircumflex', 'ENCODING': 265, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#
#   ████
# ██
#   ████
#
# {'STARTCHAR': 'Cdotaccent', 'ENCODING': 266, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██████
# ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'cdotaccent', 'ENCODING': 267, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#
#   ████
# ██
#   ████
#
# {'STARTCHAR': 'Ccaron', 'ENCODING': 268, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
# ██  ██
# ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'ccaron', 'ENCODING': 269, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
#   ████
# ██
#   ████
#
# {'STARTCHAR': 'Dcaron', 'ENCODING': 270, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
# ████
# ██  ██
# ██  ██
# ████
#
# {'STARTCHAR': 'dcaron', 'ENCODING': 271, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ████
#     ██
#   ████
# ██  ██
#   ████
#
# {'STARTCHAR': 'Dcroat', 'ENCODING': 272, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
# ██  ██
# ██████
# ██  ██
# ████
#
# {'STARTCHAR': 'dcroat', 'ENCODING': 273, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#     ██
#   ████
# ██  ██
#   ████
#
# {'STARTCHAR': 'Emacron', 'ENCODING': 274, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
# ██████
# ████
# ██
# ██████
#
# {'STARTCHAR': 'emacron', 'ENCODING': 275, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#   ██
# ██  ██
# ████
#   ████
#
# {'STARTCHAR': 'Ebreve', 'ENCODING': 276, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██████
# ████
# ██
# ██████
#
# {'STARTCHAR': 'ebreve', 'ENCODING': 277, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
# ██  ██
# ████
#   ████
#
# {'STARTCHAR': 'Edotaccent', 'ENCODING': 278, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██████
# ████
# ██
# ██████
#
# {'STARTCHAR': 'edotaccent', 'ENCODING': 279, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
# ██  ██
# ████
#   ████
#
# {'STARTCHAR': 'Eogonek', 'ENCODING': 280, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
# ██
# ████
# ██
# ██████
#     ██
# {'STARTCHAR': 'eogonek', 'ENCODING': 281, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ██
# ██  ██
# ████
#   ████
#   ██
# {'STARTCHAR': 'Ecaron', 'ENCODING': 282, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██████
# ████
# ██
# ██████
#
# {'STARTCHAR': 'ecaron', 'ENCODING': 283, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
# ██  ██
# ████
#   ████
#
# {'STARTCHAR': 'Gcircumflex', 'ENCODING': 284, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
# ██
# ██  ██
#   ████
#
# {'STARTCHAR': 'gcircumflex', 'ENCODING': 285, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
# ██  ██
#   ████
#     ██
# ████
# {'STARTCHAR': 'Gbreve', 'ENCODING': 286, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ████
# ██
# ██  ██
#   ████
#
# {'STARTCHAR': 'gbreve', 'ENCODING': 287, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
# ██  ██
#   ████
#     ██
# ████
# {'STARTCHAR': 'Gdotaccent', 'ENCODING': 288, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ████
# ██
# ██  ██
#   ████
#
# {'STARTCHAR': 'gdotaccent', 'ENCODING': 289, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ████
# ██  ██
#   ████
#     ██
# ████
# {'STARTCHAR': 'Gcommaaccent', 'ENCODING': 290, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
# ██
# ██  ██
# ██  ██
#   ██
#   ██
# {'STARTCHAR': 'gcommaaccent', 'ENCODING': 291, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ████
# ██  ██
#   ████
#     ██
# ████
# {'STARTCHAR': 'Hcircumflex', 'ENCODING': 292, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#
# ██  ██
# ██████
# ██  ██
#
# {'STARTCHAR': 'hcircumflex', 'ENCODING': 293, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
# ████
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'Hbar', 'ENCODING': 294, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██████
# ██  ██
# ██████
# ██  ██
#
# {'STARTCHAR': 'hbar', 'ENCODING': 295, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ████
# ████
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'Itilde', 'ENCODING': 296, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██  ██
# ██  ██
#   ██
#   ██
# ██████
#
# {'STARTCHAR': 'itilde', 'ENCODING': 297, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██  ██
# ██  ██
# ████
#   ██
# ██████
#
# {'STARTCHAR': 'Imacron', 'ENCODING': 298, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#
# ██████
#   ██
# ██████
#
# {'STARTCHAR': 'imacron', 'ENCODING': 299, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#
# ████
#   ██
# ██████
#
# {'STARTCHAR': 'Ibreve', 'ENCODING': 300, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
# ██████
#   ██
# ██████
#
# {'STARTCHAR': 'ibreve', 'ENCODING': 301, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
# ████
#   ██
# ██████
#
# {'STARTCHAR': 'Iogonek', 'ENCODING': 302, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#   ██
#   ██
#   ██
# ██████
#     ██
# {'STARTCHAR': 'iogonek', 'ENCODING': 303, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#
# ████
#   ██
# ██████
#     ██
# {'STARTCHAR': 'Idotaccent', 'ENCODING': 304, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#
# ██████
#   ██
# ██████
#
# {'STARTCHAR': 'dotlessi', 'ENCODING': 305, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
# ████
#   ██
# ██████
#
# {'STARTCHAR': 'IJ', 'ENCODING': 306, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ██  ██
# ██  ██
# ██  ██
#     ██
#   ████
# {'STARTCHAR': 'ij', 'ENCODING': 307, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#
# ██  ██
# ██  ██
#     ██
#   ██
# {'STARTCHAR': 'Jcircumflex', 'ENCODING': 308, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
# ██  ██
#     ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'jcircumflex', 'ENCODING': 309, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
#
#     ██
#     ██
# ████
# {'STARTCHAR': 'Kcommaaccent', 'ENCODING': 310, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██  ██
# ████
# ██  ██
#     ██
#   ██
# {'STARTCHAR': 'kcommaaccent', 'ENCODING': 311, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ██  ██
# ████
# ██  ██
#     ██
#   ██
# {'STARTCHAR': 'kgreenlandic', 'ENCODING': 312, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ██  ██
# ██  ██
# ████
# ██  ██
#
# {'STARTCHAR': 'Lacute', 'ENCODING': 313, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██
# ██
# ██
# ██████
#
# {'STARTCHAR': 'lacute', 'ENCODING': 314, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
# ████
#   ██
#   ██
# ██████
#
# {'STARTCHAR': 'Lcommaaccent', 'ENCODING': 315, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ██
# ██
# ██
# ██████
#     ██
# {'STARTCHAR': 'lcommaaccent', 'ENCODING': 316, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
#   ██
#   ██
#   ██
# ██████
#     ██
# {'STARTCHAR': 'Lcaron', 'ENCODING': 317, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ████
# ██
# ██
# ██████
#
# {'STARTCHAR': 'lcaron', 'ENCODING': 318, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████  ██
#   ██
#   ██
#   ██
# ██████
#
# {'STARTCHAR': 'Ldot', 'ENCODING': 319, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ██
# ██  ██
# ██
# ██████
#
# {'STARTCHAR': 'ldot', 'ENCODING': 320, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
#   ██
#   ██  ██
#   ██
# ██████
#
# {'STARTCHAR': 'Lslash', 'ENCODING': 321, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ██  ██
# ████
# ██
# ██████
#
# {'STARTCHAR': 'lslash', 'ENCODING': 322, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
#   ████
# ████
#   ██
# ██████
#
# {'STARTCHAR': 'Nacute', 'ENCODING': 323, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
# ██  ██
# ██████
# ██  ██
# ██
#
# {'STARTCHAR': 'nacute', 'ENCODING': 324, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
# ████
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'Ncommaaccent', 'ENCODING': 325, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
# ██  ██
# ██████
# ██  ██
# ██
#     ██
# {'STARTCHAR': 'ncommaaccent', 'ENCODING': 326, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ████
# ██  ██
# ██  ██
#
#   ██
# {'STARTCHAR': 'Ncaron', 'ENCODING': 327, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
# ██  ██
# ██████
# ██  ██
# ██
#
# {'STARTCHAR': 'ncaron', 'ENCODING': 328, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
# ████
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'napostrophe', 'ENCODING': 329, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
#
# ████
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'Eng', 'ENCODING': 330, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██████
# ██████
# ██  ██
#     ██
#   ██
# {'STARTCHAR': 'eng', 'ENCODING': 331, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ████
# ██  ██
# ██  ██
#     ██
#   ██
# {'STARTCHAR': 'Omacron', 'ENCODING': 332, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#   ██
# ██  ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'omacron', 'ENCODING': 333, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#
#   ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'Obreve', 'ENCODING': 334, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
# ██  ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'obreve', 'ENCODING': 335, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
#   ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'Ohungarumlaut', 'ENCODING': 336, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
# ██  ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'ohungarumlaut', 'ENCODING': 337, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██  ██
#   ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'OE', 'ENCODING': 338, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██  ██
# ██  ██
# ██  ████
# ██  ██
#   ██████
#
# {'STARTCHAR': 'oe', 'ENCODING': 339, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ██████
# ██  ████
# ██  ██
#   ██████
#
# {'STARTCHAR': 'Racute', 'ENCODING': 340, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
# ████
# ██  ██
# ████
# ██  ██
#
# {'STARTCHAR': 'racute', 'ENCODING': 341, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#
# ██  ██
# ████
# ██
#
# {'STARTCHAR': 'Rcommaaccent', 'ENCODING': 342, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
# ██  ██
# ████
# ██  ██
#
#   ██
# {'STARTCHAR': 'rcommaaccent', 'ENCODING': 343, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ██  ██
# ████
# ██
# ██
#     ██
# {'STARTCHAR': 'Rcaron', 'ENCODING': 344, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
# ████
# ██  ██
# ████
# ██  ██
#
# {'STARTCHAR': 'rcaron', 'ENCODING': 345, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#
# ██  ██
# ████
# ██
#
# {'STARTCHAR': 'Sacute', 'ENCODING': 346, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ████
# ████
#     ██
# ████
#
# {'STARTCHAR': 'sacute', 'ENCODING': 347, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ████
# ████
#     ██
# ████
#
# {'STARTCHAR': 'Scircumflex', 'ENCODING': 348, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
# ████
#     ██
# ████
#
# {'STARTCHAR': 'scircumflex', 'ENCODING': 349, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
# ████
#     ██
# ████
#
# {'STARTCHAR': 'Scedilla', 'ENCODING': 350, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
# ██
#   ██
#     ██
# ████
#   ██
# {'STARTCHAR': 'scedilla', 'ENCODING': 351, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ████
# ████
#     ██
# ██████
#   ██
# {'STARTCHAR': 'Scaron', 'ENCODING': 352, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
# ████
#     ██
# ██████
#
# {'STARTCHAR': 'scaron', 'ENCODING': 353, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
# ████
#     ██
# ████
#
# {'STARTCHAR': 'Tcommaaccent', 'ENCODING': 354, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#   ██
#   ██
#   ██
#     ██
#   ██
# {'STARTCHAR': 'tcommaaccent', 'ENCODING': 355, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██████
#   ██
#   ██
#     ██
#   ██
# {'STARTCHAR': 'Tcaron', 'ENCODING': 356, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
# ██████
#   ██
#   ██
#
# {'STARTCHAR': 'tcaron', 'ENCODING': 357, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
# ██████
#   ██
#     ██
#
# {'STARTCHAR': 'Tbar', 'ENCODING': 358, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#   ██
# ██████
#   ██
#   ██
#
# {'STARTCHAR': 'tbar', 'ENCODING': 359, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#   ██
# ██████
#   ██
#     ██
#
# {'STARTCHAR': 'Utilde', 'ENCODING': 360, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████  ██
#     ██
# ██  ██
# ██  ██
# ██████
#
# {'STARTCHAR': 'utilde', 'ENCODING': 361, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██  ██
# ██  ██
#
# ██  ██
#   ████
#
# {'STARTCHAR': 'Umacron', 'ENCODING': 362, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#
# ██  ██
# ██  ██
# ██████
#
# {'STARTCHAR': 'umacron', 'ENCODING': 363, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#
# ██  ██
# ██  ██
#   ████
#
# {'STARTCHAR': 'Ubreve', 'ENCODING': 364, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
# ██  ██
# ██  ██
# ██████
#
# {'STARTCHAR': 'ubreve', 'ENCODING': 365, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
#
# ██  ██
#   ████
#
# {'STARTCHAR': 'Uring', 'ENCODING': 366, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#
# ██  ██
# ██  ██
# ██████
#
# {'STARTCHAR': 'uring', 'ENCODING': 367, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#
# ██  ██
# ██  ██
#   ████
#
# {'STARTCHAR': 'Uhungarumlaut', 'ENCODING': 368, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#
# ██  ██
# ██  ██
# ██████
#
# {'STARTCHAR': 'uhungarumlaut', 'ENCODING': 369, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#
# ██  ██
# ██  ██
#   ████
#
# {'STARTCHAR': 'Uogonek', 'ENCODING': 370, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ██  ██
# ██  ██
# ██  ██
#   ██
#     ██
# {'STARTCHAR': 'uogonek', 'ENCODING': 371, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ██  ██
# ██  ██
# ██  ██
#   ████
#   ██
# {'STARTCHAR': 'Wcircumflex', 'ENCODING': 372, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
# ██  ██
# ██████
# ██  ██
#
# {'STARTCHAR': 'wcircumflex', 'ENCODING': 373, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#
# ██  ██
# ██████
# ██████
#
# {'STARTCHAR': 'Ycircumflex', 'ENCODING': 374, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#
# ██  ██
#   ██
#   ██
#
# {'STARTCHAR': 'ycircumflex', 'ENCODING': 375, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#
# ██  ██
#   ██
# ██
#
# {'STARTCHAR': 'Ydieresis', 'ENCODING': 376, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#
# ██  ██
#   ██
#   ██
#
# {'STARTCHAR': 'Zacute', 'ENCODING': 377, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██████
#   ██
# ██
# ██████
#
# {'STARTCHAR': 'zacute', 'ENCODING': 378, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██████
#   ██
# ██
# ██████
#
# {'STARTCHAR': 'Zdotaccent', 'ENCODING': 379, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██████
#   ██
# ██
# ██████
#
# {'STARTCHAR': 'zdotaccent', 'ENCODING': 380, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██████
#   ██
# ██
# ██████
#
# {'STARTCHAR': 'Zcaron', 'ENCODING': 381, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██████
#   ██
# ██
# ██████
#
# {'STARTCHAR': 'zcaron', 'ENCODING': 382, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██████
#   ██
# ██
# ██████
#
# {'STARTCHAR': 'longs', 'ENCODING': 383, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
# ████
#   ██
#   ██
#
# {'STARTCHAR': 'uni018F', 'ENCODING': 399, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ████
#   ████
# ██  ██
#   ██
#
# {'STARTCHAR': 'florin', 'ENCODING': 402, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
# ██████
#   ██
#   ██
# ██
# {'STARTCHAR': 'Scommaaccent', 'ENCODING': 536, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
# ██
#   ██
#     ██
# ████
#   ██
# {'STARTCHAR': 'scommaaccent', 'ENCODING': 537, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ████
# ████
#     ██
# ██████
#   ██
# {'STARTCHAR': 'Tcommaaccent', 'ENCODING': 538, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#   ██
#   ██
#   ██
#
#   ██
# {'STARTCHAR': 'tcommaaccent', 'ENCODING': 539, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██████
#   ██
#   ██
#     ██
#   ██
# {'STARTCHAR': 'uni0259', 'ENCODING': 601, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ████
#   ████
# ██  ██
#   ██
#
# {'STARTCHAR': 'circumflex', 'ENCODING': 710, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
#
#
#
#
# {'STARTCHAR': 'caron', 'ENCODING': 711, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██
#
#
#
#
# {'STARTCHAR': 'macron', 'ENCODING': 713, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#
#
#
#
#
# {'STARTCHAR': 'breve', 'ENCODING': 728, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██    ██
#   ████
#
#
#
#
# {'STARTCHAR': 'dotaccent', 'ENCODING': 729, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#
#
#
#
#
# {'STARTCHAR': 'ring', 'ENCODING': 730, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
#   ██
#
#
#
# {'STARTCHAR': 'ogonek', 'ENCODING': 731, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
#   ██
# ██
# ████
# {'STARTCHAR': 'tilde', 'ENCODING': 732, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██  ██
# ██  ██
#
#
#
#
# {'STARTCHAR': 'hungarumlaut', 'ENCODING': 733, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██  ██
#
#
#
#
# {'STARTCHAR': 'uni0374', 'ENCODING': 884, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
#
#
#
#
# {'STARTCHAR': 'uni0375', 'ENCODING': 885, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
#
#   ██
# ██
# {'STARTCHAR': 'uni037A', 'ENCODING': 890, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
#
#   ██
#   ████
# {'STARTCHAR': 'uni037E', 'ENCODING': 894, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ██
#
#
#   ██
# ██
# {'STARTCHAR': 'tonos', 'ENCODING': 900, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ██
#   ██
#
#
#
#
# {'STARTCHAR': 'dieresistonos', 'ENCODING': 901, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ████
#   ██
#
#
#
#
# {'STARTCHAR': 'Alphatonos', 'ENCODING': 902, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
# ██  ██
# ██████
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'anoteleia', 'ENCODING': 903, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#   ██
#
#
#
# {'STARTCHAR': 'Epsilontonos', 'ENCODING': 904, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
# ████
#   ████
#   ██
#   ████
#
# {'STARTCHAR': 'Etatonos', 'ENCODING': 905, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#     ██
# ██████
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'Iotatonos', 'ENCODING': 906, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
# ████
#   ██
#   ██
# ██████
#
# {'STARTCHAR': 'Omicrontonos', 'ENCODING': 908, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
# ██  ██
# ██  ██
# ██  ██
#   ██
#
# {'STARTCHAR': 'Upsilontonos', 'ENCODING': 910, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██  ██
# ████
#   ██
#   ██
#
# {'STARTCHAR': 'Omegatonos', 'ENCODING': 911, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
# ██  ██
# ██  ██
#   ██
# ██  ██
#
# {'STARTCHAR': 'iotadieresistonos', 'ENCODING': 912, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ████
#   ██
#
#   ██
#     ██
#
# {'STARTCHAR': 'Alpha', 'ENCODING': 913, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
# ██████
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'Beta', 'ENCODING': 914, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
# ██  ██
# ████
# ██  ██
# ████
#
# {'STARTCHAR': 'Gamma', 'ENCODING': 915, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
# ██
# ██
# ██
# ██
#
# {'STARTCHAR': 'Delta', 'ENCODING': 916, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
# ██  ██
# ██  ██
# ██████
#
# {'STARTCHAR': 'Epsilon', 'ENCODING': 917, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
# ██
# ████
# ██
# ██████
#
# {'STARTCHAR': 'Zeta', 'ENCODING': 918, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#     ██
#   ██
# ██
# ██████
#
# {'STARTCHAR': 'Eta', 'ENCODING': 919, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██  ██
# ██████
# ██  ██
# ██  ██
#
# {'STARTCHAR': 'Theta', 'ENCODING': 920, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██  ██
# ██████
# ██  ██
#   ██
#
# {'STARTCHAR': 'Iota', 'ENCODING': 921, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
#   ██
#   ██
# ...
#   ██████
# ████████
#   ██
#   ██
# {'STARTCHAR': 'uni252F', 'ENCODING': 9519, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
# ████████
# ████████
#   ██
#   ██
# {'STARTCHAR': 'uni2530', 'ENCODING': 9520, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
# ████████
#   ████
#   ████
# {'STARTCHAR': 'uni2531', 'ENCODING': 9521, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
# ██████
# ████████
#   ████
#   ████
# {'STARTCHAR': 'uni2532', 'ENCODING': 9522, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#   ██████
# ████████
#   ████
#   ████
# {'STARTCHAR': 'uni2533', 'ENCODING': 9523, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
# ████████
# ████████
#   ████
#   ████
# {'STARTCHAR': 'SF070000', 'ENCODING': 9524, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
#   ██
# ████████
#
#
# {'STARTCHAR': 'uni2535', 'ENCODING': 9525, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
# ████
# ████████
#
#
# {'STARTCHAR': 'uni2536', 'ENCODING': 9526, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
#   ██████
# ████████
#
#
# {'STARTCHAR': 'uni2537', 'ENCODING': 9527, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
# ████████
# ████████
#
#
# {'STARTCHAR': 'uni2538', 'ENCODING': 9528, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
#   ████
# ████████
#
#
# {'STARTCHAR': 'uni2539', 'ENCODING': 9529, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
# ██████
# ████████
#
#
# {'STARTCHAR': 'uni253A', 'ENCODING': 9530, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
#   ██████
# ████████
#
#
# {'STARTCHAR': 'uni253B', 'ENCODING': 9531, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
# ████████
# ████████
#
#
# {'STARTCHAR': 'SF050000', 'ENCODING': 9532, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
#   ██
# ████████
#   ██
#   ██
# {'STARTCHAR': 'uni253D', 'ENCODING': 9533, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
# ████
# ████████
#   ██
#   ██
# {'STARTCHAR': 'uni253E', 'ENCODING': 9534, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
#   ██████
# ████████
#   ██
#   ██
# {'STARTCHAR': 'uni253F', 'ENCODING': 9535, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
# ████████
# ████████
#   ██
#   ██
# {'STARTCHAR': 'uni2540', 'ENCODING': 9536, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
#   ████
# ████████
#   ██
#   ██
# {'STARTCHAR': 'uni2541', 'ENCODING': 9537, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
#   ██
# ████████
#   ████
#   ████
# {'STARTCHAR': 'uni2542', 'ENCODING': 9538, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
#   ████
# ████████
#   ████
#   ████
# {'STARTCHAR': 'uni2543', 'ENCODING': 9539, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
# ██████
# ████████
#   ██
#   ██
# {'STARTCHAR': 'uni2544', 'ENCODING': 9540, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
#   ██████
# ████████
#   ██
#   ██
# {'STARTCHAR': 'uni2545', 'ENCODING': 9541, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
# ██████
# ████████
#   ████
#   ████
# {'STARTCHAR': 'uni2546', 'ENCODING': 9542, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
#   ██████
# ████████
#   ████
#   ████
# {'STARTCHAR': 'uni2547', 'ENCODING': 9543, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
# ████████
# ████████
#   ██
#   ██
# {'STARTCHAR': 'uni2548', 'ENCODING': 9544, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
# ████████
# ████████
#   ████
#   ████
# {'STARTCHAR': 'uni2549', 'ENCODING': 9545, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
# ██████
# ████████
#   ████
#   ████
# {'STARTCHAR': 'uni254A', 'ENCODING': 9546, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
#   ██████
# ████████
#   ████
#   ████
# {'STARTCHAR': 'uni254B', 'ENCODING': 9547, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
# ████████
# ████████
#   ████
#   ████
# {'STARTCHAR': 'uni254C', 'ENCODING': 9548, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
# ██  ██
#
#
# {'STARTCHAR': 'uni254D', 'ENCODING': 9549, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
# ██  ██
# ██  ██
#
#
# {'STARTCHAR': 'uni254E', 'ENCODING': 9550, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ██
#   ██
#
#   ██
#   ██
# {'STARTCHAR': 'uni254F', 'ENCODING': 9551, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ████
#   ████
#
#   ████
#   ████
# {'STARTCHAR': 'SF430000', 'ENCODING': 9552, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
# ████████
#
# ████████
#
# {'STARTCHAR': 'SF240000', 'ENCODING': 9553, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
#   ████
#   ████
#   ████
#   ████
# {'STARTCHAR': 'SF510000', 'ENCODING': 9554, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#   ██████
#   ██
#   ██████
#   ██
# {'STARTCHAR': 'SF520000', 'ENCODING': 9555, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
#   ██████
#   ████
#   ████
# {'STARTCHAR': 'SF390000', 'ENCODING': 9556, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#   ██████
#   ██
#   ██████
#   ████
# {'STARTCHAR': 'SF220000', 'ENCODING': 9557, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
# ████
#   ██
# ████
#   ██
# {'STARTCHAR': 'SF210000', 'ENCODING': 9558, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
# ██████
#   ████
#   ████
# {'STARTCHAR': 'SF250000', 'ENCODING': 9559, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
# ██████
#     ██
# ██████
#   ████
# {'STARTCHAR': 'SF500000', 'ENCODING': 9560, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
#   ██████
#   ██
#   ██████
#
# {'STARTCHAR': 'SF490000', 'ENCODING': 9561, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
#   ████
#   ██████
#
#
# {'STARTCHAR': 'SF380000', 'ENCODING': 9562, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
#   ██████
#   ██
#   ██████
#
# {'STARTCHAR': 'SF280000', 'ENCODING': 9563, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
# ████
#   ██
# ████
#
# {'STARTCHAR': 'SF270000', 'ENCODING': 9564, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
#   ████
# ██████
#
#
# {'STARTCHAR': 'SF260000', 'ENCODING': 9565, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
# ██████
#     ██
# ██████
#
# {'STARTCHAR': 'SF360000', 'ENCODING': 9566, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
#   ██████
#   ██
#   ██████
#   ██
# {'STARTCHAR': 'SF370000', 'ENCODING': 9567, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
#   ████
#   ██████
#   ████
#   ████
# {'STARTCHAR': 'SF420000', 'ENCODING': 9568, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
#   ██████
#   ██
#   ██████
#   ████
# {'STARTCHAR': 'SF190000', 'ENCODING': 9569, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
# ████
#   ██
# ████
#   ██
# {'STARTCHAR': 'SF200000', 'ENCODING': 9570, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
#   ████
# ██████
#   ████
#   ████
# {'STARTCHAR': 'SF230000', 'ENCODING': 9571, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
# ██████
#     ██
# ██████
#   ████
# {'STARTCHAR': 'SF470000', 'ENCODING': 9572, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
# ████████
#
# ████████
#   ██
# {'STARTCHAR': 'SF480000', 'ENCODING': 9573, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
# ████████
#   ████
#   ████
# {'STARTCHAR': 'SF410000', 'ENCODING': 9574, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
# ████████
#
# ████████
#   ████
# {'STARTCHAR': 'SF450000', 'ENCODING': 9575, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
# ████████
#
# ████████
#
# {'STARTCHAR': 'SF460000', 'ENCODING': 9576, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
#   ████
# ████████
#
#
# {'STARTCHAR': 'SF400000', 'ENCODING': 9577, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
# ████████
#
# ████████
#
# {'STARTCHAR': 'SF540000', 'ENCODING': 9578, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
# ████████
#   ██
# ████████
#   ██
# {'STARTCHAR': 'SF530000', 'ENCODING': 9579, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
#   ████
# ████████
#   ████
#   ████
# {'STARTCHAR': 'SF440000', 'ENCODING': 9580, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
# ████████
#
# ████████
#   ████
# {'STARTCHAR': 'uni256D', 'ENCODING': 9581, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
#     ████
#   ██
#   ██
# {'STARTCHAR': 'uni256E', 'ENCODING': 9582, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
# ██
#   ██
#   ██
# {'STARTCHAR': 'uni256F', 'ENCODING': 9583, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
#   ██
# ██
#
#
# {'STARTCHAR': 'uni2570', 'ENCODING': 9584, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
#   ██
#     ████
#
#
# {'STARTCHAR': 'uni2571', 'ENCODING': 9585, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#       ██
#     ██
#     ██
#   ██
#   ██
# ██
# {'STARTCHAR': 'uni2572', 'ENCODING': 9586, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
#   ██
#   ██
#     ██
#     ██
#       ██
# {'STARTCHAR': 'uni2573', 'ENCODING': 9587, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██    ██
# ██    ██
#   ████
#   ████
# ██    ██
# ██    ██
# {'STARTCHAR': 'uni2574', 'ENCODING': 9588, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
# ████
#
#
# {'STARTCHAR': 'uni2575', 'ENCODING': 9589, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
#   ██
#   ██
#
#
# {'STARTCHAR': 'uni2576', 'ENCODING': 9590, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
#   ██████
#
#
# {'STARTCHAR': 'uni2577', 'ENCODING': 9591, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
#   ██
#   ██
#   ██
# {'STARTCHAR': 'uni2578', 'ENCODING': 9592, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
# ████
# ████
#
#
# {'STARTCHAR': 'uni2579', 'ENCODING': 9593, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
#   ████
#   ████
#
#
# {'STARTCHAR': 'uni257A', 'ENCODING': 9594, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#   ██████
#   ██████
#
#
# {'STARTCHAR': 'uni257B', 'ENCODING': 9595, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
#   ████
#   ████
#   ████
# {'STARTCHAR': 'uni257C', 'ENCODING': 9596, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#     ████
# ████████
#
#
# {'STARTCHAR': 'uni257D', 'ENCODING': 9597, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
#   ██
#   ████
#   ████
#   ████
# {'STARTCHAR': 'uni257E', 'ENCODING': 9598, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
# ████
# ████████
#
#
# {'STARTCHAR': 'uni257F', 'ENCODING': 9599, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ████
#   ████
#   ████
#   ████
#   ██
#   ██
# {'STARTCHAR': 'upblock', 'ENCODING': 9600, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████████
# ████████
# ████████
#
#
#
# {'STARTCHAR': 'uni2581', 'ENCODING': 9601, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
#
#
# ████████
# {'STARTCHAR': 'uni2582', 'ENCODING': 9602, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
#
#
# ████████
# {'STARTCHAR': 'uni2583', 'ENCODING': 9603, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
#
# ████████
# ████████
# {'STARTCHAR': 'dnblock', 'ENCODING': 9604, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
# ████████
# ████████
# ████████
# {'STARTCHAR': 'uni2585', 'ENCODING': 9605, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
#
# ████████
# ████████
# ████████
# {'STARTCHAR': 'uni2586', 'ENCODING': 9606, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
# ████████
# ████████
# ████████
# ████████
# {'STARTCHAR': 'uni2587', 'ENCODING': 9607, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ████████
# ████████
# ████████
# ████████
# ████████
# {'STARTCHAR': 'block', 'ENCODING': 9608, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████████
# ████████
# ████████
# ████████
# ████████
# ████████
# {'STARTCHAR': 'uni2589', 'ENCODING': 9609, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████████
# ████████
# ████████
# ████████
# ████████
# ████████
# {'STARTCHAR': 'uni258A', 'ENCODING': 9610, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
# ██████
# ██████
# ██████
# ██████
# ██████
# {'STARTCHAR': 'uni258B', 'ENCODING': 9611, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██████
# ██████
# ██████
# ██████
# ██████
# ██████
# {'STARTCHAR': 'lfblock', 'ENCODING': 9612, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
# ████
# ████
# ████
# ████
# ████
# {'STARTCHAR': 'uni258D', 'ENCODING': 9613, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████
# ████
# ████
# ████
# ████
# ████
# {'STARTCHAR': 'uni258E', 'ENCODING': 9614, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ██
# ██
# ██
# ██
# ██
# {'STARTCHAR': 'uni258F', 'ENCODING': 9615, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ██
# ██
# ██
# ██
# ██
# {'STARTCHAR': 'rtblock', 'ENCODING': 9616, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#     ████
#     ████
#     ████
#     ████
#     ████
#     ████
# {'STARTCHAR': 'ltshade', 'ENCODING': 9617, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
#     ██
# ██
#     ██
# ██
#     ██
# {'STARTCHAR': 'shade', 'ENCODING': 9618, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
#   ██  ██
# ██  ██
#   ██  ██
# ██  ██
#   ██  ██
# {'STARTCHAR': 'dkshade', 'ENCODING': 9619, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ████
# ██████
# ██  ████
# ██████
# ██  ████
# ██████
# {'STARTCHAR': 'uni2594', 'ENCODING': 9620, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████████
#
#
#
#
#
# {'STARTCHAR': 'uni2595', 'ENCODING': 9621, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#       ██
#       ██
#       ██
#       ██
#       ██
#       ██
# {'STARTCHAR': 'filledbox', 'ENCODING': 9632, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
# ██████
# ██████
# ██████
#
# {'STARTCHAR': 'H22073', 'ENCODING': 9633, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#
# ██████
# ██  ██
# ██████
#
# {'STARTCHAR': 'uni25C6', 'ENCODING': 9670, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ██
# ██████
# ██████
#   ██
#
# {'STARTCHAR': 'spade', 'ENCODING': 9824, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
# ██████
# ██████
#   ██
# ██████
#
# {'STARTCHAR': 'club', 'ENCODING': 9827, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ██
# ██  ██
#   ██
# ██████
#
# {'STARTCHAR': 'heart', 'ENCODING': 9829, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
# ██  ██
# ██████
# ██████
#   ██
#
# {'STARTCHAR': 'diamond', 'ENCODING': 9830, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#
#   ██
# ██████
#   ██
#
#
# {'STARTCHAR': 'uni2669', 'ENCODING': 9833, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ██
#   ██
# ████
# ██
#
# {'STARTCHAR': 'musicalnote', 'ENCODING': 9834, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██
#   ████
#   ██
# ████
# ██
#
# {'STARTCHAR': 'musicalnotedbl', 'ENCODING': 9835, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██████
#   ██  ██
#   ██  ██
#   ██  ██
# ██  ██
#
# {'STARTCHAR': 'uni266C', 'ENCODING': 9836, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
#   ██████
#   ██████
#   ██  ██
#   ██  ██
# ██  ██
#
# {'STARTCHAR': 'uni266D', 'ENCODING': 9837, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ██
# ██████
# ██  ██
# ████
#
# {'STARTCHAR': 'uni266E', 'ENCODING': 9838, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██
# ██████
# ██  ██
# ██████
#     ██
#
# {'STARTCHAR': 'uni266F', 'ENCODING': 9839, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ██  ██
# ██████
# ██  ██
# ██████
# ██  ██
#
# {'STARTCHAR': 'uniFFFD', 'ENCODING': 65533, 'SWIDTH': 640, 'DWIDTH': 4, 'BBX': 4}
# ████████
# ██    ██
# ████  ██
# ████████
# ████  ██
# ████████

# %%
K,H,W = alldata.shape
M = int(ceil(sqrt(K)))

grid = zeros(((W+1)*M,(H+1)*M))

idx = 0
for i in range(M):
    for j in range(M):
        grid[i*(W+1):(i+1)*(W+1)-1,j*(H+1):(j+1)*(H+1)-1]=alldata[idx].T
        idx+=1
        if idx>=K: break
    if idx>=K: break

figure(figsize=(20,20))
imshow(grid.T,interpolation='nearest',cmap='bone_r')
